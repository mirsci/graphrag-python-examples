# %% [markdown]
# # GraphRAG Python package End-to-End Example
#
# This notebook contains an end-to-end worked example using the [GraphRAG Python package](https://neo4j.com/docs/neo4j-graphrag-python/current/index.html) for Neo4j. It starts with unstructured documents (in this case pdfs), and progresses through knowledge graph construction, knowledge graph retriever design, and complete GraphRAG pipelines.
#
# Research papers on Lupus are used as the data source. We design a couple of different retrievers based on different knowledge graph retrieval patterns.
#
# For more details and explanations around each of the below steps, see the [corresponding blog post](https://neo4j.com/blog/graphrag-python-package/) which contains a full write-up, in-depth comparison of the retrieval patterns, and additional learning resources.
#
# ## Pre-Requisites
#
# 1. __Create a Neo4j Database__: To work through this RAG example, you need a database for storing and retrieving data. There are many options for this. You can quickly start a free Neo4j Graph Database using [Neo4j AuraDB](https://neo4j.com/product/auradb/?ref=neo4j-home-hero). You can use __AuraDB Free__ or start an __AuraDB Professional (Pro) free trial__ for higher ingestion and retrieval performance. The Pro instances have a bit more RAM; we recommend them for the best user experience.
# 2. __Obtain an OpenAI Key__: This example requires an OpenAI API key to use language models and embedders. The cost should be very minimal. If you do not yet have an OpenAI API key you can [create an OpenAI account](https://platform.openai.com/signup) or [sign in](https://platform.openai.com/login). Next, navigate to the [API key page](https://platform.openai.com/account/api-keys) and click "Create new secret key". Optionally naming the key.
# 3. __Fill in Credentials__: Either by copying the [`.env.template`](.env.template) file, naming it `.env`, and filling in the appropriate credentials, or by manually putting the credentials into the second code cell below. You will need:
#     1. The Neo4j URI, username, and password variables from when you created the database. If you created your database on AuraDB, they are in the file you downloaded.
#     2. Your OpenAI API key.

# %% [markdown]
# ## Setup

# %%
# %%capture
# %pip install fsspec langchain-text-splitters tiktoken openai python-dotenv numpy torch neo4j-graphrag

# %%
from dotenv import load_dotenv
import os

# load neo4j credentials (and openai api key in background).
# load_dotenv('.env', override=True)
# NEO4J_URI = os.getenv('NEO4J_URI')
# NEO4J_USERNAME = os.getenv('NEO4J_USERNAME')
# NEO4J_PASSWORD = os.getenv('NEO4J_PASSWORD')

NEO4J_URI = ""
NEO4J_USERNAME = ""
NEO4J_PASSWORD = ""

#uncomment this line if you aren't using a .env file
# os.environ['OPENAI_API_KEY'] = ''

# %% [markdown]
# ## Knowledge Graph Building
#
# The `SimpleKGPipeline` class allows you to automatically build a knowledge graph with a few key inputs, including
# - a driver to connect to Neo4j,
# - an LLM for entity extraction, and
# - an embedding model to create vectors on text chunks for similarity search.
#
# There are also some optional inputs, such as node labels, relationship types, and a custom prompt template, which we will use to improve the quality of the knowledge graph. For full details on this, see [the blog](https://neo4j.com/blog/graphrag-python-package/).

# %%
import neo4j
from neo4j_graphrag.llm import OpenAILLM
from neo4j_graphrag.embeddings.openai import OpenAIEmbeddings

driver = neo4j.GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

ex_llm=OpenAILLM(
    model_name="gpt-4o-mini",
    model_params={
        "response_format": {"type": "json_object"}, # use json_object formatting for best results
        "temperature": 0 # turning temperature down for more deterministic results
    }
)

#create text embedder
embedder = OpenAIEmbeddings()

# %%
#define node labels
basic_node_labels = ["Object", "Entity", "Group", "Person", "Organization", "Place"]

academic_node_labels = ["ArticleOrPaper", "PublicationOrJournal"]

medical_node_labels = ["Anatomy", "BiologicalProcess", "Cell", "CellularComponent",
                       "CellType", "Condition", "Disease", "Drug",
                       "EffectOrPhenotype", "Exposure", "GeneOrProtein", "Molecule",
                       "MolecularFunction", "Pathway"]

node_labels = basic_node_labels + academic_node_labels + medical_node_labels

# define relationship types
rel_types = ["ACTIVATES", "AFFECTS", "ASSESSES", "ASSOCIATED_WITH", "AUTHORED",
    "BIOMARKER_FOR", "CAUSES", "CITES", "CONTRIBUTES_TO", "DESCRIBES", "EXPRESSES",
    "HAS_REACTION", "HAS_SYMPTOM", "INCLUDES", "INTERACTS_WITH", "PRESCRIBED",
    "PRODUCES", "RECEIVED", "RESULTS_IN", "TREATS", "USED_FOR"]

# %%
prompt_template = '''
You are a medical researcher tasks with extracting information from papers
and structuring it in a property graph to inform further medical and research Q&A.

Extract the entities (nodes) and specify their type from the following Input text.
Also extract the relationships between these nodes. the relationship direction goes from the start node to the end node.


Return result as JSON using the following format:
{{"nodes": [ {{"id": "0", "label": "the type of entity", "properties": {{"name": "name of entity" }} }}],
  "relationships": [{{"type": "TYPE_OF_RELATIONSHIP", "start_node_id": "0", "end_node_id": "1", "properties": {{"details": "Description of the relationship"}} }}] }}

- Use only the information from the Input text.  Do not add any additional information.
- If the input text is empty, return empty Json.
- Make sure to create as many nodes and relationships as needed to offer rich medical context for further research.
- An AI knowledge assistant must be able to read this graph and immediately understand the context to inform detailed research questions.
- Multiple documents will be ingested from different sources and we are using this property graph to connect information, so make sure entity types are fairly general.

Use only fhe following nodes and relationships (if provided):
{schema}

Assign a unique ID (string) to each node, and reuse it to define relationships.
Do respect the source and target node types for relationship and
the relationship direction.

Do not return any additional information other than the JSON in it.

Examples:
{examples}

Input text:

{text}
'''

# %%
from neo4j_graphrag.experimental.components.text_splitters.fixed_size_splitter import FixedSizeSplitter
from neo4j_graphrag.experimental.pipeline.kg_builder import SimpleKGPipeline

kg_builder_pdf = SimpleKGPipeline(
    llm=ex_llm,
    driver=driver,
    text_splitter=FixedSizeSplitter(chunk_size=500, chunk_overlap=100),
    embedder=embedder,
    entities=node_labels,
    relations=rel_types,
    prompt_template=prompt_template,
    from_pdf=True
)

# %% [markdown]
# Below, we run the `SimpleKGPipeline` to construct our knowledge graph from 3 pdf documents and store in Neo4j.

# %%
pdf_file_paths = ['truncated-pdfs/biomolecules-11-00928-v2-trunc.pdf', ]
            #  'truncated-pdfs/GAP-between-patients-and-clinicians_2023_Best-Practice-trunc.pdf',
            #  'truncated-pdfs/pgpm-13-39-trunc.pdf']

for path in pdf_file_paths:
    print(f"Processing : {path}")
    pdf_result = await kg_builder_pdf.run_async(file_path=path)
    print(f"Result: {pdf_result}")
# Out:
# Processing : truncated-pdfs/biomolecules-11-00928-v2-trunc.pdf
# Result: run_id='4b641922-6745-407d-9cb3-309de9180709' result={'resolver': {'number_of_nodes_to_resolve': 961, 'number_of_created_nodes': 757}}

# %% [markdown]
# ## Knowledge Graph Retrieval

# %% [markdown]
# We will leverage Neo4j's vector search capabilities here. To do this, we need to begin by creating a vector index on the text chunks from the PDFs, which are stored on `Chunk` nodes in our knowledge graph.

# %%
from neo4j_graphrag.indexes import create_vector_index

create_vector_index(driver, name="text_embeddings", label="Chunk",
                    embedding_property="embedding", dimensions=1536, similarity_fn="cosine")

# %% [markdown]
# Now that the index is set up, we will start simple with a __VectorRetriever__.  The __VectorRetriever__ just queries `Chunk` nodes via vector search, bringing back the text and some metadata.

# %%
from neo4j_graphrag.retrievers import VectorRetriever

vector_retriever = VectorRetriever(
    driver,
    index_name="text_embeddings",
    embedder=embedder,
    return_properties=["text"],
)

# %% [markdown]
# Below we visualize the context we get back when submitting a search prompt.

# %%
import json

vector_res = vector_retriever.get_search_results(query_text = "How is precision medicine applied to Lupus?",
                                                 top_k=3)
for i in vector_res.records: print("====\n" + json.dumps(i.data(), indent=4))
# Out:
# ====
# {
#     "node": {
#         "text": "icine for patients with SLE.\nTable 2. Clinical and immunological biomarkers of organ-speci\ufb01c damage in SLE.\nOrgan-Speci\ufb01c\nDamage in SLEBiomarkers Sample Type Key Points Refs\nLupus nephritisAnti-dsDNA antibodies SerumAssociated with SLE disease activity and can\npredict the development of LN; high\nspeci\ufb01city (96%), low diagnostic sensitivity\n(52\u201370%).[18,50\u201352]\nAnti-Sm antibodies SerumCorrelates with SLE disease activity and LN;\nhighly speci\ufb01c diagnostic biomarker for SLE\nwith a speci\ufb01city of 99% "
#     },
#     "nodeLabels": [
#         "Chunk",
#         "__KGBuilder__"
#     ],
#     "elementId": "4:85364395-2265-4a7b-a09d-38e54c19b43a:58",
#     "id": "4:85364395-2265-4a7b-a09d-38e54c19b43a:58",
#     "score": 0.9138336181640625
# }
# ====
# {
#     "node": {
#         "text": "endothelial damage and premature\natherosclerosis in SLE, and thus they are useful therapeutic targets for preventing CVD\nin SLE patients [ 84]. In addition, serum levels of IgG-anticardiolipin antibodies [ 85] and\nE-selectin [86] are associated with CVD in lupus and correlated with disease activity.\n6. Omics Approaches in SLE\nOmics approaches provide opportunities for revealing new biomarkers for SLE to\ntrack the disease course with greater sensitivity and speci\ufb01city. Omics, including the\n"
#     },
#     "nodeLabels": [
#         "Chunk",
#         "__KGBuilder__"
#     ],
#     "elementId": "4:85364395-2265-4a7b-a09d-38e54c19b43a:92",
#     "id": "4:85364395-2265-4a7b-a09d-38e54c19b43a:92",
#     "score": 0.911865234375
# }
# ====
# {
#     "node": {
#         "text": "h for treating SLE can only control the symptoms and delay the\nprogression of the disease but cannot cure it completely [ 1]. It is critical to improve the\nability to diagnose SLE early for effective treatment. Therefore, biomarkers, especially\nimmunological biomarkers, have emerged to help better diagnose SLE and assess its patho-\nphysiological processes, with the ultimate goal of improving control of the disease. The\naim of the current study was to review immunological biomarkers for SLE "
#     },
#     "nodeLabels": [
#         "Chunk",
#         "__KGBuilder__"
#     ],
#     "elementId": "4:85364395-2265-4a7b-a09d-38e54c19b43a:9",
#     "id": "4:85364395-2265-4a7b-a09d-38e54c19b43a:9",
#     "score": 0.907440185546875
# }

# %% [markdown]
# The GraphRAG Python Package offers [a wide range of useful retrievers](https://neo4j.com/docs/neo4j-graphrag-python/current/user_guide_rag.html#retriever-configuration), each covering different knowledge graph retrieval patterns.
#
# Below we will use the __`VectorCypherRetriever`__, which allows you to run a graph traversal after finding nodes with vector search.  This uses Cypher, Neo4j's graph query language, to define the logic for traversing the graph.
#
# As a simple starting point, we'll traverse up to 3 hops out from each Chunk, capture the relationships encountered, and include them in the response alongside our text chunks.

# %%
from neo4j_graphrag.retrievers import VectorCypherRetriever

vc_retriever = VectorCypherRetriever(
    driver,
    index_name="text_embeddings",
    embedder=embedder,
    retrieval_query="""
//1) Go out 2-3 hops in the entity graph and get relationships
WITH node AS chunk
MATCH (chunk)<-[:FROM_CHUNK]-()-[relList:!FROM_CHUNK]-{1,2}()
UNWIND relList AS rel

//2) collect relationships and text chunks
WITH collect(DISTINCT chunk) AS chunks,
  collect(DISTINCT rel) AS rels

//3) format and return context
RETURN '=== text ===\n' + apoc.text.join([c in chunks | c.text], '\n---\n') + '\n\n=== kg_rels ===\n' +
  apoc.text.join([r in rels | startNode(r).name + ' - ' + type(r) + '(' + coalesce(r.details, '') + ')' +  ' -> ' + endNode(r).name ], '\n---\n') AS info
"""
)

# %% [markdown]
# Below we visualize the context we get back when submitting a search prompt.

# %%
vc_res = vc_retriever.get_search_results(query_text = "How is precision medicine applied to Lupus?", top_k=3)

# print output
kg_rel_pos = vc_res.records[0]['info'].find('\n\n=== kg_rels ===\n')
print("# Text Chunk Context:")
print(vc_res.records[0]['info'][:kg_rel_pos])
print("# KG Context From Relationships:")
print(vc_res.records[0]['info'][kg_rel_pos:])
# Out:
# # Text Chunk Context:
# === text ===
# icine for patients with SLE.
# Table 2. Clinical and immunological biomarkers of organ-speciﬁc damage in SLE.
# Organ-Speciﬁc
# Damage in SLEBiomarkers Sample Type Key Points Refs
# Lupus nephritisAnti-dsDNA antibodies SerumAssociated with SLE disease activity and can
# predict the development of LN; high
# speciﬁcity (96%), low diagnostic sensitivity
# (52–70%).[18,50–52]
# Anti-Sm antibodies SerumCorrelates with SLE disease activity and LN;
# highly speciﬁc diagnostic biomarker for SLE
# with a speciﬁcity of 99%
# ---
# endothelial damage and premature
# atherosclerosis in SLE, and thus they are useful therapeutic targets for preventing CVD
# in SLE patients [ 84]. In addition, serum levels of IgG-anticardiolipin antibodies [ 85] and
# E-selectin [86] are associated with CVD in lupus and correlated with disease activity.
# 6. Omics Approaches in SLE
# Omics approaches provide opportunities for revealing new biomarkers for SLE to
# track the disease course with greater sensitivity and speciﬁcity. Omics, including the
#
# ---
# h for treating SLE can only control the symptoms and delay the
# progression of the disease but cannot cure it completely [ 1]. It is critical to improve the
# ability to diagnose SLE early for effective treatment. Therefore, biomarkers, especially
# immunological biomarkers, have emerged to help better diagnose SLE and assess its patho-
# physiological processes, with the ultimate goal of improving control of the disease. The
# aim of the current study was to review immunological biomarkers for SLE
# # KG Context From Relationships:
#
#
# === kg_rels ===
# alterations of fecal metabolites - ASSOCIATED_WITH(alterations of fecal metabolites are closely correlated with SLE) -> SLE
# ---
# methylation level of the IFI44L promoter - ASSOCIATED_WITH(The methylation level is associated with SLE.) -> SLE
# ---
# cells - HAS_SYMPTOM(The methylation level of the IFI44L promoter is a diagnostic marker for SLE.) -> methylation level of the IFI44L promoter
# ---
# SLE pathogenesis - ASSOCIATED_WITH(Epigenetic alterations play a key role in SLE pathogenesis.) -> SLE
# ---
# environmental factors - AFFECTS(Epigenetic markers can be influenced by environmental factors.) -> SLE pathogenesis
# ---
# SLE pathogenesis - AFFECTS(Dysregulation of gene expression.) -> gene expression
# ---
# genome-wide approaches - DESCRIBES(Genome-wide approaches employed to elucidate epigenetic differences.) -> SLE pathogenesis
# ---
# Cardiovascular disease (CVD) - ASSOCIATED_WITH(Cardiovascular disease is an important complication of SLE) -> SLE
# ---
# Cardiovascular disease (CVD) - INCLUDES(low-density granulocytes-to-high-density lipoprotein is a biomarker for CVD) -> low-density granulocytes-to-high-density lipoprotein
# ---
# Cardiovascular disease (CVD) - INCLUDES(monocyte-to-high-density lipoprotein cholesterol ratio is a biomarker for CVD) -> monocyte-to-high-density lipoprotein cholesterol ratio
# ---
# highly specific biomarker - ASSOCIATED_WITH(Highly specific biomarker is associated with SLE) -> SLE
# ---
# Anti-RibP Serum - BIOMARKER_FOR(Anti-RibP Serum is a highly specific biomarker for SLE) -> highly specific biomarker
# ---
# subacute cutaneous lupus - ASSOCIATED_WITH(Anti-SSA antibodies are associated with subacute cutaneous lupus) -> SLE
# ---
# anti-SSA antibodies - BIOMARKER_FOR(anti-SSA antibodies are associated with subacute cutaneous lupus) -> subacute cutaneous lupus
# ---
# Serum ANA - ASSOCIATED_WITH(Serum ANA is associated with the condition SLE.) -> SLE
# ---
# Non-Organ-Specific Biomarkers for SLE - DESCRIBES(The article describes Serum ANA as a biomarker.) -> Serum ANA
# ---
# Serum ANA - DESCRIBES() -> SLE
# ---
# EULAR/ACR-2019 SLE classification - ASSOCIATED_WITH(EULAR/ACR-2019 SLE classification is related to SLE.) -> SLE
# ---
# ACR-1997 classification criteria - CITES(Comparison of classification criteria for SLE.) -> EULAR/ACR-2019 SLE classification
# ---
# EULAR/ACR-2019 SLE classification - INCLUDES(EULAR/ACR-2019 SLE classification includes clinical indices.) -> clinical indices
# ---
# EULAR/ACR-2019 SLE classification - INCLUDES(EULAR/ACR-2019 SLE classification includes immunologic biomarkers.) -> immunologic biomarkers
# ---
# ACR SLE classification criteria - ASSOCIATED_WITH(ACR SLE classification criteria is related to SLE) -> SLE
# ---
# SLICC - AUTHORED(SLICC group revised and validated the ACR SLE classification criteria) -> ACR SLE classification criteria
# ---
# TNF - ASSOCIATED_WITH(TNF is associated with SLE) -> SLE
# ---
# TNF - BIOMARKER_FOR(TNF is a biomarker for SLE) -> SLE
# ---
# Sm - ASSOCIATED_WITH(Sm is associated with SLE) -> SLE
# ---
# Sm - BIOMARKER_FOR(Sm is a biomarker for SLE) -> SLE
# ---
# Sm - ASSOCIATED_WITH() -> SLE
# ---
# PON1 - ASSOCIATED_WITH(PON1 is associated with SLE) -> SLE
# ---
# PON1 - BIOMARKER_FOR(PON1 is a biomarker for SLE) -> SLE
# ---
# nLHR - ASSOCIATED_WITH(nLHR is associated with SLE) -> SLE
# ---
# nLHR - BIOMARKER_FOR(nLHR is a biomarker for SLE) -> SLE
# ---
# MHR - ASSOCIATED_WITH(MHR is associated with SLE) -> SLE
# ---
# MHR - BIOMARKER_FOR(MHR is a biomarker for SLE) -> SLE
# ---
# MHR - ASSOCIATED_WITH(MHR is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# MCP-1 - ASSOCIATED_WITH(MCP-1 is associated with SLE) -> SLE
# ---
# Chemokines - INCLUDES(Chemokines include MCP-1) -> MCP-1
# ---
# MCP-1 - BIOMARKER_FOR(MCP-1 is a biomarker for SLE) -> SLE
# ---
# IL - ASSOCIATED_WITH(IL is associated with SLE) -> SLE
# ---
# IL - RESULTS_IN(IL is related to SLE) -> SLE
# ---
# IL - BIOMARKER_FOR(IL is a biomarker for SLE) -> SLE
# ---
# IFN - ASSOCIATED_WITH(IFN is associated with SLE) -> SLE
# ---
# IFN - RESULTS_IN(IFN is related to SLE) -> SLE
# ---
# IFN - BIOMARKER_FOR(IFN is a biomarker for SLE) -> SLE
# ---
# IgG - ASSOCIATED_WITH(IgG is associated with SLE) -> SLE
# ---
# IgG - RESULTS_IN(IgG is related to SLE) -> SLE
# ---
# IgG - BIOMARKER_FOR(IgG is a biomarker for SLE) -> SLE
# ---
# IgG - ASSOCIATED_WITH() -> SLE
# ---
# double-stranded DNA - ASSOCIATED_WITH(double-stranded DNA is associated with SLE) -> SLE
# ---
# IP-10 - ASSOCIATED_WITH(IP-10 is associated with SLE) -> SLE
# ---
# IP-10 - RESULTS_IN(IP-10 is related to SLE) -> SLE
# ---
# Chemokines - INCLUDES(Chemokines include IP-10) -> IP-10
# ---
# IP-10 - BIOMARKER_FOR(IP-10 is a biomarker for SLE) -> SLE
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(IP-10 is a symptom of SLE) -> IP-10
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with the kidneys.) -> kidneys
# ---
# SLE - ASSOCIATED_WITH(The metabolome is considered to play a key role in SLE.) -> metabolome
# ---
# Systemic Lupus Erythematosus (SLE) - CONTRIBUTES_TO(The metabolome plays a key role in SLE) -> metabolome
# ---
# SLE - ASSOCIATED_WITH(SLE can be separated from patients with other autoimmune diseases.) -> other autoimmune diseases
# ---
# SLE - ASSOCIATED_WITH(SLE can be separated from healthy persons.) -> healthy persons
# ---
# SLE - ASSOCIATED_WITH(SLE activity is associated with skin lesions) -> skin lesions
# ---
# disease activity in LN - HAS_SYMPTOM(disease activity in LN associated with skin lesions) -> skin lesions
# ---
# AhR ratio - ASSOCIATED_WITH(AhR ratio associated with skin lesions) -> skin lesions
# ---
# SLE - ASSOCIATED_WITH(Lupus nephritis is a condition associated with SLE.) -> Lupus nephritis
# ---
# SLE - ASSOCIATED_WITH(positive ANA is associated with SLE diagnosis) -> positive ANA
# ---
# SLE - ASSOCIATED_WITH(low C3 and C4 levels are associated with SLE diagnosis) -> low C3 and C4 levels
# ---
# low C3 and C4 levels - AFFECTS(low C3 and C4 levels positively correlate with SLE disease activity) -> SLE disease activity
# ---
# low C3 and C4 levels - AFFECTS(low C3 and C4 levels can precede a clinically evident flare) -> clinically evident flare
# ---
# SLE - ASSOCIATED_WITH(low levels of C4 are associated with SLE) -> low levels of C4
# ---
# low levels of C4 - RESULTS_IN(low levels of C4 contribute to diagnosis with SLE) -> diagnosis with SLE
# ---
# SLE - ASSOCIATED_WITH(low levels of C3 are associated with SLE) -> low levels of C3
# ---
# low levels of C3 - RESULTS_IN(low levels of C3 contribute to diagnosis with SLE) -> diagnosis with SLE
# ---
# SLE - ASSOCIATED_WITH(SLE reflects inflammation.) -> inflammation
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(SLE reflects inflammation.) -> inflammation
# ---
# SLE - ASSOCIATED_WITH(SLE reflects immune reactivity.) -> immune reactivity
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(SLE reflects immune reactivity.) -> immune reactivity
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with reflecting the therapeutic effect of interventions for SLE) -> reflecting the therapeutic effect of interventions for SLE
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with assessing SLE disease activity) -> assessing SLE disease activity
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with classifying SLE complications) -> classifying SLE complications
# ---
# SLE - ASSOCIATED_WITH(Finding an ideal biomarker for SLE) -> biomarker
# ---
# biomarker - INCLUDES(biomarker can be reliably measured in fluids) -> fluids
# ---
# biomarker - INCLUDES(biomarker can be reliably measured in cells) -> cells
# ---
# biomarker - INCLUDES(biomarker can be reliably measured in tissues) -> tissues
# ---
# biomarker - AFFECTS(biomarker monitors SLE flares) -> SLE flares
# ---
# biomarker - AFFECTS(biomarker monitors SLE activity) -> SLE activity
# ---
# biomarker - ASSOCIATED_WITH(biomarker has high specificity) -> high specificity
# ---
# biomarker - ASSOCIATED_WITH(biomarker has high sensitivity) -> high sensitivity
# ---
# biomarker - ASSOCIATED_WITH(biomarker has high predictive values) -> high predictive values
# ---
# biomarker - ASSOCIATED_WITH(biomarker has validity) -> validity
# ---
# biomarker - ASSOCIATED_WITH(biomarker has reliability) -> reliability
# ---
# biomarker - DESCRIBES(biomarker reflects the treatment target) -> treatment target
# ---
# biomarker - DESCRIBES(biomarker reflects the underlying pathophysiology) -> pathophysiology
# ---
# combining multiple biomarkers through mathematical models - CONTRIBUTES_TO(multiple biomarkers combined through mathematical models may be a good idea for assessing SLE) -> SLE
# ---
# multiple biomarkers - CONTRIBUTES_TO(Multiple biomarkers contribute to understanding SLE.) -> SLE
# ---
# identifying genetic risk loci for SLE susceptibility - CONTRIBUTES_TO(Identifying genetic risk loci contributes to understanding SLE susceptibility.) -> SLE
# ---
# Genome-wide association studies (GWAS) - DESCRIBES(GWAS describes the process of identifying genetic risk loci.) -> identifying genetic risk loci for SLE susceptibility
# ---
# SLE - ASSESSES(Epigenetic differences in B cell subsets in patients with SLE) -> B cell subsets
# ---
# B cell subsets - ASSESSES(Comparison with similar subsets derived from healthy control subjects) -> healthy control subjects
# ---
# SLE - INCLUDES(B cell subsets in patients with SLE.) -> B cell subsets
# ---
# epigenetic analyses - DESCRIBES(Epigenetic analyses of B cell subsets) -> B cell subsets
# ---
# coronin-1A - RESULTS_IN(level of coronin-1A in serum can distinguish LN patients from SLE patients without nephritis) -> SLE
# ---
# coronin-1A - DESCRIBES(coronin-1A is a biomarker of LN) -> biomarker of LN
# ---
# dsDNA - RESULTS_IN(dsDNA is related to SLE) -> SLE
# ---
# dsDNA - BIOMARKER_FOR(dsDNA is a biomarker for SLE) -> SLE
# ---
# dsDNA - ASSOCIATED_WITH() -> SLE
# ---
# anti-SSA - RESULTS_IN(anti-SSA is related to SLE) -> SLE
# ---
# anti-RibP - RESULTS_IN(anti-RibP is related to SLE) -> SLE
# ---
# anti-NMDAR - RESULTS_IN(anti-NMDAR is related to SLE) -> SLE
# ---
# SLE - RESULTS_IN(SLE patients are at risk for CVD) -> CVD risk
# ---
# SLE - RESULTS_IN(Higher serum anti-NMDAR levels in NPSLE patients) -> serum anti-NMDAR levels
# ---
# Serum Anti-Sm Antibody - INCLUDES(Presence of anti-Sm antibodies is included in SLE classification criteria) -> SLE
# ---
# Serum Anti-Sm Antibody - CORRELATED_WITH(Anti-Sm antibodies are correlated with SLE disease activity) -> SLE disease activity
# ---
# Serum Anti-Sm Antibody - BIOMARKER_FOR(Anti-Sm antibodies serve as a biomarker for SLE classification) -> SLE
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers are related to SLE) -> SLE
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include lupus erythematosus (LE) cells.) -> lupus erythematosus (LE) cells
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include complement (2, 3, and 4).) -> complement (2, 3, and 4)
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include total complement activity.) -> total complement activity
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include DNA antibody.) -> DNA antibody
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include antinuclear antibody (ANA).) -> antinuclear antibody (ANA)
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include Smith (Sm) antibody.) -> Smith (Sm) antibody
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include platelets.) -> platelets
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include lymphocytes.) -> lymphocytes
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include white blood cells.) -> white blood cells
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include hemolytic anemia with reticulocytosis.) -> hemolytic anemia with reticulocytosis
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include urinary casts.) -> urinary casts
# ---
# laboratory biomarkers - INCLUDES(laboratory biomarkers include proteinuria.) -> proteinuria
# ---
# Rheumatology (ACR) - ASSOCIATED_WITH(Rheumatology (ACR) is associated with laboratory biomarkers.) -> laboratory biomarkers
# ---
# College of Rheumatology (ACR) - ASSOCIATED_WITH(ACR contains laboratory biomarkers) -> laboratory biomarkers
# ---
# SLE - INCLUDES(SLE requires at least one immunologic criterion) -> immunologic criterion
# ---
# immunologic criterion - USED_FOR(double-stranded DNA (dsDNA) antibodies are used for categorizing SLE) -> double-stranded DNA (dsDNA) antibodies
# ---
# immunologic criterion - USED_FOR(ANAs are used for categorizing SLE) -> ANAs
# ---
# SLE - INCLUDES(Measurement sites in patients with SLE are included in the study of SLE) -> measurement sites in patients with SLE
# ---
# SLE - INCLUDES(Common biomarkers for SLE are included in the study of SLE) -> Common biomarkers for SLE
# ---
# biomarker sensitivity and specificity for SLE - AFFECTS(biomarker can be sensitive and specific for SLE) -> SLE
# ---
# advanced computational methods for analyzing large datasets - CONTRIBUTES_TO(advanced computational methods are required to analyze large datasets and discover novel biomarkers) -> biomarker sensitivity and specificity for SLE
# ---
# K.F. - AUTHORED(K.F. professionally edited the manuscript) -> biomarker sensitivity and specificity for SLE
# ---
# Y.N. - AUTHORED(Y.N. professionally edited the manuscript) -> biomarker sensitivity and specificity for SLE
# ---
# H.Y. - AUTHORED(H.Y. conceived the presented idea and drafted the manuscript) -> biomarker sensitivity and specificity for SLE
# ---
# granzyme B - AFFECTS(granzyme B is increased in the serum and kidneys of patients with SLE) -> SLE
# ---
# granzyme B - AFFECTS(granzyme B is correlated with a poor prognosis of LN) -> poor prognosis
# ---
# NPSLE - AFFECTS(NPSLE affects SLE patients) -> SLE
# ---
# diagnostic biomarkers - DIAGNOSTIC_FOR(Diagnostic biomarkers are used for NPSLE) -> NPSLE
# ---
# CVD risk in SLE patients - PREDICTS(CVD risk in SLE patients predicts NPSLE) -> NPSLE
# ---
# NPSLE - CAUSES(NPSLE manifestations are caused by certain antibodies) -> diagnostic biomarkers
# ---
# therapeutic biomarker for SLE patients with CVD - PRODUCES(Therapeutic biomarker for SLE patients with CVD produces NPSLE) -> NPSLE
# ---
# treatment decisions - USED_FOR(Treatment decisions are made for NPSLE) -> NPSLE
# ---
# NPSLE - RESULTS_IN(NPSLE is used to make treatment decisions) -> treatment decisions
# ---
# NPSLE - AFFECTS(NPSLE affects the peripheral nervous system) -> peripheral nervous system
# ---
# NPSLE - AFFECTS(NPSLE affects the central nervous system) -> central nervous system
# ---
# NPSLE - AFFECTS(NPSLE affects treatment decisions) -> treatment decisions
# ---
# accelerated atherosclerosis in lupus - BIOMARKER_FOR(Accelerated atherosclerosis in lupus is a biomarker for NPSLE) -> NPSLE
# ---
# highly specific biomarker - BIOMARKER_FOR(Anti-RibP is a highly specific biomarker for NPSLE) -> NPSLE
# ---
# NPSLE - HAS_SYMPTOM(NPSLE manifestations are symptoms of NPSLE) -> NPSLE manifestations
# ---
# anti-RibP test - ASSOCIATED_WITH(anti-RibP is associated with NPSLE) -> NPSLE
# ---
# VGLL-3 - ASSOCIATED_WITH(VGLL-3 is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# VCAM-1 - ASSOCIATED_WITH(VCAM-1 is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# ocyte chemoattractant protein-1 - ASSOCIATED_WITH(ocyte chemoattractant protein-1 is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# incident cardiovascular events in SLE patients - ASSOCIATED_WITH(Incident cardiovascular events in SLE patients are associated with NPSLE) -> NPSLE
# ---
# associated with NPSLE - ASSOCIATED_WITH(Associated with NPSLE) -> NPSLE
# ---
# uTWEAK - ASSOCIATED_WITH(uTWEAK is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# TGF-β - ASSOCIATED_WITH(TGF-β is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# RANTES - ASSOCIATED_WITH(RANTES is associated with neuropsychiatric systemic lupus erythematosus) -> NPSLE
# ---
# NPSLE - ASSOCIATED_WITH(NPSLE is associated with diagnostic biomarkers.) -> diagnostic biomarkers
# ---
# NPSLE - ASSOCIATED_WITH(NPSLE is a severe complication of lupus) -> lupus
# ---
# NPSLE - ASSOCIATED_WITH(NPSLE is associated with cardiovascular disease) -> cardiovascular disease
# ---
# NPSLE - ASSOCIATED_WITH(NPSLE is a severe complication of lupus) -> lupus
# ---
# NPSLE - ASSOCIATED_WITH(NPSLE is associated with the publication Biomolecules 2021) -> Biomolecules 2021
# ---
# SLE disease activity - AFFECTS(SLE disease activity affects the condition SLE.) -> SLE
# ---
# SLE disease activity - RESULTS_IN(SLE disease activity can predict the development of LN.) -> development of LN
# ---
# SLE - AFFECTS(SLE affects disease progression.) -> disease progression
# ---
# SLE - AFFECTS(SLE correlates with a poor prognosis of LN.) -> poor prognosis of LN
# ---
# SLE - AFFECTS(Disease environment shaping epigenetic networks of B cells) -> epigenetic networks
# ---
# SLE - AFFECTS(SLE can cause multiple organ damage) -> multiple organ damage
# ---
# SLE - AFFECTS(SLE can be complicated with renal or hematologic flares) -> SLE complicated with renal or hematologic flares
# ---
# SLE - AFFECTS(SLE affects the likelihood of missed diagnosis) -> missed diagnosis
# ---
# SLE - AFFECTS(SLE is diagnosed based on laboratory biomarkers.) -> laboratory biomarkers
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is diagnosed based on laboratory biomarkers.) -> laboratory biomarkers
# ---
# SLE - AFFECTS(SLE is diagnosed based on signs.) -> signs
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is diagnosed based on signs.) -> signs
# ---
# SLE - AFFECTS(SLE is diagnosed based on clinical symptoms.) -> clinical symptoms
# ---
# clinical symptoms - INCLUDES(Clinical symptoms include early stages of disease) -> early stages of disease
# ---
# SLE - HAS_SYMPTOM(SLE has clinical symptoms) -> clinical symptoms
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is diagnosed based on clinical symptoms.) -> clinical symptoms
# ---
# SLE - AFFECTS(SLE can cause damage to various organs) -> damage to various organs
# ---
# organ-specific SLE biomarkers - BIOMARKER_FOR(Organ-specific SLE biomarkers are needed for SLE.) -> SLE
# ---
# non-organ-specific SLE biomarkers - BIOMARKER_FOR(Non-organ-specific SLE biomarkers are needed for SLE.) -> SLE
# ---
# immunological biomarkers - BIOMARKER_FOR(Immunological biomarkers are needed for SLE.) -> SLE
# ---
# anti-RibP test - BIOMARKER_FOR(anti-RibP is a biomarker for diagnosing SLE) -> SLE
# ---
# anti-RibP test - INCLUDES(anti-RibP test includes immunoblot) -> immunoblot
# ---
# anti-RibP test - INCLUDES(anti-RibP test includes immunodiffusion) -> immunodiffusion
# ---
# anti-RibP test - INCLUDES(anti-RibP test includes ELISA) -> ELISA
# ---
# anti-RibP variability - HAS_SYMPTOM(Variability of anti-RibP test results) -> anti-RibP test
# ---
# anti-C1q antibodies - BIOMARKER_FOR(anti-C1q antibodies may serve as a non-invasive biomarker for predicting renal flares in SLE) -> SLE
# ---
# anti-C1q antibodies - ASSOCIATED_WITH(anti-C1q antibodies can be found in Stevens-Johnson syndrome) -> Stevens-Johnson syndrome
# ---
# anti-C1q antibodies - ASSOCIATED_WITH(anti-C1q antibodies can be found in rheumatoid arthritis) -> rheumatoid arthritis
# ---
# anti-C1q antibodies - ASSOCIATED_WITH(anti-C1q antibodies can be found in Sjögren’s syndrome) -> Sjögren’s syndrome
# ---
# anti-C1q antibodies - ASSOCIATED_WITH(anti-C1q antibodies can be found in hypocomplementemic urticarial vasculitis) -> hypocomplementemic urticarial vasculitis
# ---
# Anti-Sm antibodies - BIOMARKER_FOR(Anti-Sm antibodies are highly specific diagnostic biomarkers for SLE.) -> SLE
# ---
# Anti-dsDNA antibodies - BIOMARKER_FOR(Anti-dsDNA antibodies are biomarkers associated with SLE disease activity.) -> SLE
# ---
# biomarker for screening, classification, diagnosis, prognosis, and staging - BIOMARKER_FOR(used as a biomarker for) -> SLE
# ---
# ideal biomarker for SLE - BIOMARKER_FOR(Ideal biomarker for SLE is a biomarker for SLE) -> SLE
# ---
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects the underlying pathophysiology or treatment target) -> underlying pathophysiology or treatment target
# ---
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects high sensitivity) -> high sensitivity
# ---
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects high predictive values) -> high predictive values
# ---
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects validity) -> validity
# ---
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects reliability) -> reliability
# ---
# biomarker - BIOMARKER_FOR(A biomarker may reflect one specific aspect of SLE) -> SLE
# ---
# biomarker - ASSESSES(Biomarkers can be used to detect and/or monitor a biologic process) -> biologic process
# ---
# SLE - BIOMARKER_FOR(SLE patients with atheromatosis have high ratios indicating CVD risk) -> CVD
# ---
# serum cardiac troponin T - BIOMARKER_FOR(serum cardiac troponin T is a biomarker for incident cardiovascular events in SLE patients) -> CVD
# ---
# SLE - ASSOCIATED_WITH(SLE patients may have CVD) -> CVD
# ---
# CVD - ASSOCIATED_WITH(CVD is associated with atheromatosis in SLE patients) -> atheromatosis
# ---
# SLE - HAS_SYMPTOM(The presence of IIF-ANA titer of 1:80 or more serves as an entry criterion for SLE.) -> IIF-ANA titer of 1:80 or more
# ---
# SLE - HAS_SYMPTOM(Positive ANA is an obligatory entry criterion for SLE.) -> Positive ANA
# ---
# SLE - HAS_SYMPTOM(SLE exhibits cardiovascular symptoms) -> cardiovascular symptoms
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(SLE includes cardiovascular symptoms) -> cardiovascular symptoms
# ---
# SLE - HAS_SYMPTOM(SLE exhibits neuropsychiatric symptoms) -> neuropsychiatric symptoms
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(SLE includes neuropsychiatric symptoms) -> neuropsychiatric symptoms
# ---
# SLE - HAS_SYMPTOM(SLE exhibits dermatological symptoms) -> dermatological symptoms
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(SLE includes dermatological symptoms) -> dermatological symptoms
# ---
# SLE - HAS_SYMPTOM(SLE exhibits renal symptoms) -> renal symptoms
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(SLE includes renal symptoms) -> renal symptoms
# ---
# EULAR/ACR-2019 classification criteria - DESCRIBES(EULAR/ACR-2019 classification criteria describes SLE diagnosis) -> SLE
# ---
# SLICC-2012 classification criteria - DESCRIBES(SLICC-2012 classification criteria describes SLE) -> SLE
# ---
# SLICC-2012 classification criteria - AFFECTS(SLICC-2012 classification criteria shows improved sensitivity and lower specificity compared to ACR-1997 classification criteria) -> ACR-1997 classification criteria
# ---
# American College of Rheumatology (ACR) - DESCRIBES(ACR established classification criteria for SLE.) -> SLE
# ---
# American College of Rheumatology (ACR) - AUTHORED(ACR established classification criteria for SLE.) -> classification criteria
# ---
# clinical and immunological biomarkers review - DESCRIBES(This article reviews clinical and immunological biomarkers for SLE) -> SLE
# ---
# Systemic Lupus Erythematosus (SLE) - INTERACTS_WITH(SLE cells interact with healthy controls) -> healthy controls
# ---
# specificity - AFFECTS(can occur in) -> healthy controls
# ---
# Biomarker for Staging - USED_FOR(ANA is used as a biomarker for staging of SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Biomarker for Prognosis - USED_FOR(ANA is used as a biomarker for prognosis of SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Biomarker for Diagnosis - USED_FOR(ANA is used as a biomarker for diagnosis of SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Biomarker for Classification - USED_FOR(ANA is used as a biomarker for classification of SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Biomarker for Screening - USED_FOR(ANA is used as a biomarker for screening SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# clinical relevance - CONTRIBUTES_TO(Improving clinical relevance of SLE criteria) -> Systemic Lupus Erythematosus (SLE)
# ---
# Assessment of patho-physiological processes - CONTRIBUTES_TO(Assessment of patho-physiological processes helps in understanding SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# C-Reactive Protein (CRP) - ASSESSES(CRP can be used for monitoring SLE disease activity) -> Systemic Lupus Erythematosus (SLE)
# ---
# C-Reactive Protein (CRP) - ASSOCIATED_WITH(CRP levels are associated with inflammation) -> inflammation
# ---
# Erythrocyte Sedimentation Rate (ESR) - ASSESSES(ESR can be used for monitoring SLE disease activity) -> Systemic Lupus Erythematosus (SLE)
# ---
# Erythrocyte Sedimentation Rate (ESR) - ASSOCIATED_WITH(ESR is a key sign of inflammation) -> inflammation
# ---
# Antinuclear Antibody (ANA) Testing - ASSESSES(ANA Testing assesses the condition SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Antinuclear Antibody (ANA) Testing - INCLUDES(ANA Testing includes antigen-specific ANAs Testing) -> Antigen-specific ANAs Testing
# ---
# Diagnostic and Therapeutic Criteria Committee of the ACR - ASSESSES(Revised classification criteria for SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Diagnosis - ASSESSES(Early diagnosis is critical for effective treatment) -> Systemic Lupus Erythematosus (SLE)
# ---
# C4 - ASSESSES(C4 is assessed for diagnosing SLE) -> Diagnosis
# ---
# C3 - ASSESSES(C3 is assessed for diagnosing SLE) -> Diagnosis
# ---
# Anti-Nucleosome Antibodies (ANuA) - INCLUDES(ANuA can be combined with clinical findings for diagnosing SLE) -> Diagnosis
# ---
# Drug-Induced Lupus - TREATS(Drug-Induced Lupus is a condition related to SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Treatment - TREATS(Treatment aims to control SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# IFN-stimulated genes (ISGs) - RESULTS_IN(High levels of ISGs can distinguish SLE cells from healthy controls) -> Systemic Lupus Erythematosus (SLE)
# ---
# IFN-stimulated genes (ISGs) - ASSOCIATED_WITH(ISGs are associated with Lupus Nephritis) -> Lupus Nephritis (LN)
# ---
# Control of the disease - RESULTS_IN(Improving control of the disease is the ultimate goal) -> Systemic Lupus Erythematosus (SLE)
# ---
# Systemic Lupus Erythematosus (SLE) - RESULTS_IN(SLE disease activity is indicated by ESR and CRP levels) -> disease activity
# ---
# anti-dsDNA antibodies - AFFECTS(anti-dsDNA antibodies are an unreliable biomarker for assessing disease activity) -> disease activity
# ---
# SLE - AFFECTS(biomarkers reflect disease activity of SLE) -> disease activity
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(SLE is associated with disease activity) -> disease activity
# ---
# disease activity - ASSOCIATED_WITH(Disease activity is associated with LN) -> LN
# ---
# Systemic Lupus Erythematosus (SLE) - RESULTS_IN(SLE progression cannot be cured completely) -> Progression of SLE
# ---
# Systemic Lupus Erythematosus (SLE) - RESULTS_IN(The prevalence of SLE is measured) -> prevalence
# ---
# Systemic Lupus Erythematosus (SLE) - RESULTS_IN(The incidence of SLE is measured) -> incidence
# ---
# Systemic Lupus Erythematosus (SLE) - INCLUDES(SLE presents with a wide range of clinical manifestations) -> wide range of clinical manifestations
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(SLE causes endothelial damage.) -> endothelial damage
# ---
# endothelial damage - RESULTS_IN(Endothelial damage results in premature atherosclerosis.) -> premature atherosclerosis
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(Systemic Lupus Erythematosus (SLE) can lead to active nephritis) -> active nephritis
# ---
# Systemic Lupus Erythematosus (SLE) - AFFECTS(SLE is associated with glomerulonephritis) -> glomerulonephritis
# ---
# C4 - BIOMARKER_FOR(C4 levels are biomarkers for SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# C3 - BIOMARKER_FOR(C3 levels are biomarkers for SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Immunological biomarkers - BIOMARKER_FOR(Immunological biomarkers help in diagnosing SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Current study on immunological biomarkers for SLE - AUTHORED(Current study reviews immunological biomarkers for SLE) -> Immunological biomarkers
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(Positive ANA Result is a symptom of SLE) -> Positive ANA Result
# ---
# Positive ANA Result - INTERACTS_WITH(Positive ANA Result interacts with Ribonuclear Protein) -> Ribonuclear Protein
# ---
# Positive ANA Result - INTERACTS_WITH(Positive ANA Result interacts with Sm) -> Sm
# ---
# Positive ANA Result - INTERACTS_WITH(Positive ANA Result interacts with Sjögren’s syndrome antigen B) -> Sjögren’s syndrome antigen B
# ---
# Positive ANA Result - INTERACTS_WITH(Positive ANA Result interacts with Sjögren’s syndrome antigen A (SSA (Ro60))) -> Sjögren’s syndrome antigen A (SSA (Ro60))
# ---
# Positive ANA Result - INTERACTS_WITH(Positive ANA Result interacts with dsDNA) -> dsDNA
# ---
# Systemic Lupus Erythematosus (SLE) - HAS_SYMPTOM(SLE can control the symptoms) -> Symptoms
# ---
# anti-dsDNA antibodies - ASSOCIATED_WITH(anti-dsDNA antibodies are associated with Systemic Lupus Erythematosus (SLE)) -> Systemic Lupus Erythematosus (SLE)
# ---
# anti-dsDNA antibodies - RESULTS_IN(anti-dsDNA antibodies have a transient appearance) -> transient appearance
# ---
# anti-dsDNA antibodies - AFFECTS(anti-dsDNA antibodies drive cytokine production) -> cytokine production
# ---
# anti-dsDNA antibodies - ASSOCIATED_WITH(anti-dsDNA antibodies can exacerbate active LN) -> active LN
# ---
# Detection of anti-dsDNA antibodies - DESCRIBES(The paper discusses the detection of anti-dsDNA antibodies) -> anti-dsDNA antibodies
# ---
# ANuA - ASSOCIATED_WITH(ANuA is related to Systemic Lupus Erythematosus (SLE)) -> Systemic Lupus Erythematosus (SLE)
# ---
# ANuA - RESULTS_IN(The probability that a subject with positive ANuA has SLE is 41 times greater than a subject with negative ANuA) -> probability of SLE diagnosis
# ---
# ANuA - RESULTS_IN(The negative likelihood ratio of ANuA is 0.38) -> negative likelihood ratio
# ---
# ANuA - RESULTS_IN(The overall positive likelihood ratio of ANuA is 13.81) -> positive likelihood ratio
# ---
# Anti-Nucleosome Antibodies (ANuA) - ASSOCIATED_WITH(ANuA is associated with SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Anti-Nucleosome Antibodies (ANuA) - RESULTS_IN(Presence of ANuA is related to glomerulonephritis) -> Glomerulonephritis
# ---
# immunological basis of SLE - ASSOCIATED_WITH(Immunological basis of SLE) -> Systemic Lupus Erythematosus (SLE)
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> Plasma cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> Dendritic cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> Natural Killer cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> CD8+ T cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> CD4+ T cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> Monocytes
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE activity is classified by subpopulations of enriched ISGs and/or monogenic lupus-associated genes.) -> B cells
# ---
# B cells - RESULTS_IN(B cells result in transcription factors) -> transcription factors
# ---
# Omics - INCLUDES(Omics includes B cells) -> B cells
# ---
# age-associated B-cell signature - AFFECTS(age-associated B-cell signature is correlated with B cells) -> B cells
# ---
# Lupus Nephritis (LN) - ASSOCIATED_WITH(local activation of B cells is correlated with LN) -> B cells
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is associated with an increased risk of CVD.) -> Cardiovascular Disease (CVD)
# ---
# E-selectin - ASSOCIATED_WITH(E-selectin is associated with CVD in lupus.) -> Cardiovascular Disease (CVD)
# ---
# IgG-anticardiolipin antibodies - ASSOCIATED_WITH(IgG-anticardiolipin antibodies are associated with CVD in lupus.) -> Cardiovascular Disease (CVD)
# ---
# Cardiovascular Disease (CVD) - ASSOCIATED_WITH(CVD is associated with SLE patients.) -> SLE patients
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE can be associated with arthritis) -> arthritis
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE can be associated with serositis) -> serositis
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(Immunologic criteria related to SLE) -> immunologic criteria
# ---
# purpura - AFFECTS(purpura is associated with immunologic criteria) -> immunologic criteria
# ---
# anticardiolipin antibodies - BIOMARKER_FOR(Anticardiolipin antibodies as a biomarker for immunologic criteria) -> immunologic criteria
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes an abnormal titer of antinuclear antibody) -> An abnormal titer of antinuclear antibody
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes immobilization or fluorescent treponemal antibody absorption test) -> immobilization or fluorescent treponemal antibody absorption test
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes false positive serologic test for syphilis) -> False positive serologic test for syphilis
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes presence of antibodies to Sm nuclear antigen) -> Presence of antibodies to Sm nuclear antigen
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes presence of antibodies to Sm) -> Presence of antibodies to Sm
# ---
# immunologic criteria - HAS_SYMPTOM(immunologic criteria includes platelet count < 100,000/mm3) -> Platelet count < 100,000/mm3
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(Healthcare-related costs are related to SLE) -> healthcare-related costs
# ---
# healthcare-related costs - AFFECTS(Healthcare-related costs are related to disease severity) -> disease severity
# ---
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is characterized by aberrant activity of the immune system) -> aberrant activity of the immune system
# ---
# Omics Approaches in SLE - DESCRIBES(Omics approaches provide opportunities for revealing new biomarkers for SLE.) -> Systemic Lupus Erythematosus (SLE)
# ---
# ACR SLE classification criteria - DESCRIBES(ACR SLE classification criteria) -> Systemic Lupus Erythematosus (SLE)
# ---
# Systemic Lupus International Collaborating Clinics (SLICC) - AUTHORED(Revised and validated ACR SLE classification criteria) -> ACR SLE classification criteria
# ---
# SLE - RESULTS_IN(SLE can result in premature atherosclerosis) -> premature atherosclerosis
# ---
# biomarkers - PRODUCES(play a crucial role in diagnosing SLE) -> SLE
# ---
# SLE - TREATS(Multidisciplinary approach treats SLE) -> multidisciplinary approach
# ---
# SLE - RESULTS_IN(SLE can result in endothelial damage) -> endothelial damage
# ---
# SLE - RESULTS_IN(reflecting the therapeutic) -> reflecting the therapeutic
# ---
# SLE - RESULTS_IN(assessing SLE disease activity) -> assessing SLE disease activity
# ---
# SLE - RESULTS_IN(classifying SLE complications) -> classifying SLE complications
# ---
# SLE - RESULTS_IN(diagnosing SLE) -> diagnosing SLE
# ---
# SLE - RESULTS_IN(SLE results in mean annual direct medical cost) -> mean annual direct medical cost
# ---
# SLE - AFFECTS(SLE affects the disease course tracking) -> disease course tracking
# ---
# SLE - AFFECTS(Up to 30% of patients with SLE screened in clinical trials for new therapies are ANA-negative.) -> 30%
# ---
# SLE - AFFECTS(biomarkers reflect therapeutic effect of interventions for SLE) -> therapeutic effect
# ---
# SLE - AFFECTS(SLE affects disease severity) -> disease severity
# ---
# diagnostic biomarker - BIOMARKER_FOR(Diagnostic biomarker for SLE) -> SLE
# ---
# SLE Activity - ASSOCIATED_WITH(The AhR ratio is associated with SLE activity.) -> SLE
# ---
# Hereditary C1q deficiency - ASSOCIATED_WITH(Hereditary C1q deficiency is associated with SLE) -> SLE
# ---
# lupus - ASSOCIATED_WITH(lupus is associated with SLE) -> SLE
# ---
# SLICC - ASSOCIATED_WITH() -> SLE
# ---
# LDH - ASSOCIATED_WITH() -> SLE
# ---
# IgM - ASSOCIATED_WITH() -> SLE
# ---
# IgA - ASSOCIATED_WITH() -> SLE
# ---
# anti-β2GPI - ASSOCIATED_WITH() -> SLE
# ---
# biomarkers - ASSOCIATED_WITH(biomarkers are used in the diagnosis and management of SLE) -> SLE
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with all-cause mortality) -> all-cause mortality
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with renal dysfunction) -> renal dysfunction
# ---
# SLE - ASSOCIATED_WITH(SLE is associated with organ injury) -> organ injury
# ---
# SLE - ASSOCIATED_WITH(Skin lesions are typical clinical manifestations of SLE.) -> Skin Lesions
# ---
# SLE - ASSOCIATED_WITH(SLE patients may have CVD) -> CVD
# ---
# SLE - ASSOCIATED_WITH(A negative ANA test cannot rule out SLE diagnosis.) -> ANA test
# ---
# SLE - ASSOCIATED_WITH(Healthcare-related costs are associated with SLE) -> healthcare-related costs
# ---
# high-density lipoprotein - BIOMARKER_FOR(high-density lipoprotein is a potential biomarker of premature atherosclerosis) -> premature atherosclerosis

# %% [markdown]
# ## GraphRAG
#
#  You can construct GraphRAG pipelines with the `GraphRAG` class.  At a minimum, you will need to pass the constructor an LLM and a retriever. You can optionally pass a custom prompt template. We will do so here just to provide a bit more guidance for the LLM to stick to information from our data source.
#
# Below we create `GraphRAG` objects for both the vector and vector-cypher retrievers.

# %%
from neo4j_graphrag.llm import OpenAILLM as LLM
from neo4j_graphrag.generation import RagTemplate
from neo4j_graphrag.generation.graphrag import GraphRAG

llm = LLM(model_name="gpt-4o",  model_params={"temperature": 0.0})

rag_template = RagTemplate(template='''Answer the Question using the following Context. Only respond with information mentioned in the Context. Do not inject any speculative information not mentioned.

# Question:
{query_text}

# Context:
{context}

# Answer:
''', expected_inputs=['query_text', 'context'])

v_rag  = GraphRAG(llm=llm, retriever=vector_retriever, prompt_template=rag_template)
vc_rag = GraphRAG(llm=llm, retriever=vc_retriever, prompt_template=rag_template)

# %% [markdown]
# Now we can run GraphRAG and examine the outputs.

# %%
q = "How is precision medicine applied to Lupus? provide in list format."
print(f"Vector Response: \n{v_rag.search(q, retriever_config={'top_k':5}).answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag.search(q, retriever_config={'top_k':5}).answer}")
# Out:
# Vector Response:
# - Use of anti-dsDNA antibodies in serum to predict the development of lupus nephritis (LN) and assess SLE disease activity.
# - Use of anti-Sm antibodies in serum as a highly specific diagnostic biomarker for SLE, correlating with disease activity and LN.
# - Application of omics approaches to reveal new biomarkers for tracking the disease course of SLE with greater sensitivity and specificity.
#
# ===========================
#
# Vector + Cypher Response:
# - Use of clinical and immunological biomarkers to assess organ-specific damage in SLE.
# - Application of omics approaches to reveal new biomarkers for tracking the disease course with greater sensitivity and specificity.
# - Use of renal biopsy as the gold standard for diagnosing, classifying, and prognosing lupus nephritis, despite its limitations.
# - Identification of specific antibodies, such as anti-dsDNA and anti-Sm, as biomarkers associated with SLE disease activity and lupus nephritis.
# - Utilization of the EULAR/ACR-2019 SLE classification criteria, which include clinical indices and immunologic biomarkers, to improve sensitivity and specificity in SLE diagnosis.

# %%
q = "Can you summarize systemic lupus erythematosus (SLE)? including common effects, biomarkers, and treatments? Provide in detailed list format."

v_rag_result = v_rag.search(q, retriever_config={'top_k': 5}, return_context=True)
vc_rag_result = vc_rag.search(q, retriever_config={'top_k': 5}, return_context=True)

print(f"Vector Response: \n{v_rag_result.answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag_result.answer}")
# Out:
# Vector Response:
# - **Systemic Lupus Erythematosus (SLE):**
#   - **Nature:** SLE is a systemic autoimmune disease characterized by aberrant activity of the immune system.
#   - **Clinical Manifestations:** It presents with a wide range of clinical symptoms and signs due to its ability to cause damage to various organs.
#
# - **Common Effects:**
#   - SLE can cause organ-specific damage, such as lupus nephritis.
#
# - **Biomarkers:**
#   - **Anti-dsDNA antibodies:** Found in serum, associated with SLE disease activity, and can predict the development of lupus nephritis (LN). It has high specificity (96%) but low diagnostic sensitivity (52–70%).
#   - **Anti-Sm antibodies:** Found in serum, correlates with SLE disease activity and LN, and is a highly specific diagnostic biomarker for SLE with a specificity of 99%.
#
# - **Diagnosis and Classification:**
#   - SLE is diagnosed and classified based on clinical symptoms, signs, and laboratory biomarkers that reflect immune reactivity and inflammation in various organs.
#   - The American College of Rheumatology (ACR) established widely used classification criteria for SLE, which include laboratory biomarkers like proteinuria and urinary casts.
#
# - **Challenges in Biomarker Identification:**
#   - Finding an ideal biomarker for SLE is challenging because it should reflect the underlying pathophysiology or treatment target, have reliability, validity, high predictive values, and high sensitivity.
#   - One particular biomarker may only reflect one specific aspect of SLE and may not be useful for reflecting the state of the disease as a whole.
#
# - **Research and Monitoring:**
#   - Novel SLE biomarkers have been discovered through "omics" research, which are used to diagnose and monitor disease activity in SLE, with and without organ-specific injury.
#
# ===========================
#
# Vector + Cypher Response:
# - **Systemic Lupus Erythematosus (SLE):**
#   - A systemic autoimmune disease characterized by aberrant activity of the immune system.
#   - Presents with a wide range of clinical manifestations.
#
# - **Common Effects:**
#   - Can cause damage to various organs.
#   - Associated with cardiovascular disease (CVD), neuropsychiatric symptoms, dermatological symptoms, and renal symptoms.
#   - Can lead to complications such as lupus nephritis and glomerulonephritis.
#
# - **Biomarkers:**
#   - **Common Biomarkers:**
#     - Anti-dsDNA antibodies: Associated with SLE disease activity.
#     - Anti-Sm antibodies: Highly specific diagnostic biomarker for SLE.
#     - Serum ANA: Used for diagnosis and monitoring.
#     - Low levels of C3 and C4: Associated with SLE diagnosis and disease activity.
#   - **Organ-Specific Biomarkers:**
#     - Lupus nephritis: Anti-dsDNA antibodies and Anti-Sm antibodies.
#   - **Novel Biomarkers:**
#     - Discovered through "omics" research.
#   - **Other Biomarkers:**
#     - Anti-RibP, anti-SSA antibodies, and anti-C1q antibodies.
#
# - **Treatments:**
#   - Treatment aims to control SLE and manage symptoms.
#   - Reflects the therapeutic effect of interventions for SLE.
#   - Treatment decisions are influenced by disease activity and specific symptoms.
#
# - **Diagnosis and Classification:**
#   - Based on clinical symptoms, signs, and laboratory biomarkers.
#   - Classification criteria established by the American College of Rheumatology (ACR).
#   - Includes laboratory biomarkers like proteinuria, urinary casts, and antinuclear antibody (ANA).
#
# - **Disease Activity and Monitoring:**
#   - Biomarkers are used to assess SLE disease activity and monitor flares.
#   - C-Reactive Protein (CRP) and Erythrocyte Sedimentation Rate (ESR) can be used for monitoring disease activity.

# %%
for i in v_rag_result.retriever_result.items: print(json.dumps(eval(i.content), indent=1))
# Out:
# {
#  "text": "SLE, classifying SLE complications, \nassessing SLE disease activity, and reflecting the therapeutic effect of interventions for \nSLE. Common biomarkers for SLE and their me asurement sites in patients with SLE are \nhighlighted in Figure 1. Finding an ideal biomarker for SLE is challenging because it should have the following characteristics: (1 ) reflect the underlying pathophysiology or \ntreatment target; (2) have reliability, validity, high predictive values, and high sensitivity \nand "
# }
# {
#  "text": "and immunological biomarkers that could diagnose and monitor disease activity in SLE, with and\nwithout organ-speci\ufb01c injury. In addition, novel SLE biomarkers that have been discovered through\n\u201comics\u201d research are also reviewed.\nKeywords: systemic lupus erythematosus; biomarkers; diagnosis; monitoring; omics\n1. Introduction\nSystemic lupus erythematosus (SLE) is a systemic autoimmune disease characterized\nby aberrant activity of the immune system [ 1] and presents with a wide range of clinical\n"
# }
# {
#  "text": "icine for patients with SLE.\nTable 2. Clinical and immunological biomarkers of organ-speci\ufb01c damage in SLE.\nOrgan-Speci\ufb01c\nDamage in SLEBiomarkers Sample Type Key Points Refs\nLupus nephritisAnti-dsDNA antibodies SerumAssociated with SLE disease activity and can\npredict the development of LN; high\nspeci\ufb01city (96%), low diagnostic sensitivity\n(52\u201370%).[18,50\u201352]\nAnti-Sm antibodies SerumCorrelates with SLE disease activity and LN;\nhighly speci\ufb01c diagnostic biomarker for SLE\nwith a speci\ufb01city of 99% "
# }
# {
#  "text": "E Diagnosis and Classi\ufb01cation\nSLE is diagnosed and classi\ufb01ed based on a patient\u2019s clinical symptoms, signs, and\nlaboratory biomarkers that re\ufb02ect immune reactivity and in\ufb02ammation in various organs.\nIt is necessary to develop consistent classi\ufb01cation criteria of SLE for research and clinical\ndiagnosis. The most widely used classi\ufb01cation criteria for SLE was established by the\nAmerican College of Rheumatology (ACR) and contains laboratory biomarkers, including\nproteinuria, urinary casts, "
# }
# {
#  "text": "13]. Because SLE can cause damage to various organs, has a complex pathogenesis,\nand displays heterogeneous clinical manifestations, one particular biomarker may only\nre\ufb02ect one speci\ufb01c aspect of SLE but not be useful for re\ufb02ecting the state of the disease as a\nwhole [14,15].\nBiomolecules 2021 , 11, x FOR PEER REVIEW 2 of 16 \n \nbiochemical, molecular, or genetic character and can be used to detect and/or monitor a \nbiologic process or morbid state by a qualit ative and/or quantitative test [9]. "
# }

# %%
vc_ls = vc_rag_result.retriever_result.items[0].content.split('\\n---\\n')
for i in vc_ls:
    if "biomarker" in i: print(i)
# Out:
# <Record info='=== text ===\nSLE, classifying SLE complications, \nassessing SLE disease activity, and reflecting the therapeutic effect of interventions for \nSLE. Common biomarkers for SLE and their me asurement sites in patients with SLE are \nhighlighted in Figure 1. Finding an ideal biomarker for SLE is challenging because it should have the following characteristics: (1 ) reflect the underlying pathophysiology or \ntreatment target; (2) have reliability, validity, high predictive values, and high sensitivity \nand
# and immunological biomarkers that could diagnose and monitor disease activity in SLE, with and\nwithout organ-speciﬁc injury. In addition, novel SLE biomarkers that have been discovered through\n“omics” research are also reviewed.\nKeywords: systemic lupus erythematosus; biomarkers; diagnosis; monitoring; omics\n1. Introduction\nSystemic lupus erythematosus (SLE) is a systemic autoimmune disease characterized\nby aberrant activity of the immune system [ 1] and presents with a wide range of clinical\n
# icine for patients with SLE.\nTable 2. Clinical and immunological biomarkers of organ-speciﬁc damage in SLE.\nOrgan-Speciﬁc\nDamage in SLEBiomarkers Sample Type Key Points Refs\nLupus nephritisAnti-dsDNA antibodies SerumAssociated with SLE disease activity and can\npredict the development of LN; high\nspeciﬁcity (96%), low diagnostic sensitivity\n(52–70%).[18,50–52]\nAnti-Sm antibodies SerumCorrelates with SLE disease activity and LN;\nhighly speciﬁc diagnostic biomarker for SLE\nwith a speciﬁcity of 99%
# E Diagnosis and Classiﬁcation\nSLE is diagnosed and classiﬁed based on a patient’s clinical symptoms, signs, and\nlaboratory biomarkers that reﬂect immune reactivity and inﬂammation in various organs.\nIt is necessary to develop consistent classiﬁcation criteria of SLE for research and clinical\ndiagnosis. The most widely used classiﬁcation criteria for SLE was established by the\nAmerican College of Rheumatology (ACR) and contains laboratory biomarkers, including\nproteinuria, urinary casts,
# 13]. Because SLE can cause damage to various organs, has a complex pathogenesis,\nand displays heterogeneous clinical manifestations, one particular biomarker may only\nreﬂect one speciﬁc aspect of SLE but not be useful for reﬂecting the state of the disease as a\nwhole [14,15].\nBiomolecules 2021 , 11, x FOR PEER REVIEW 2 of 16 \n \nbiochemical, molecular, or genetic character and can be used to detect and/or monitor a \nbiologic process or morbid state by a qualit ative and/or quantitative test [9]. \n\n=== kg_rels ===\nalterations of fecal metabolites - ASSOCIATED_WITH(alterations of fecal metabolites are closely correlated with SLE) -> SLE
# Cardiovascular disease (CVD) - INCLUDES(low-density granulocytes-to-high-density lipoprotein is a biomarker for CVD) -> low-density granulocytes-to-high-density lipoprotein
# Cardiovascular disease (CVD) - INCLUDES(monocyte-to-high-density lipoprotein cholesterol ratio is a biomarker for CVD) -> monocyte-to-high-density lipoprotein cholesterol ratio
# highly specific biomarker - ASSOCIATED_WITH(Highly specific biomarker is associated with SLE) -> SLE
# Anti-RibP Serum - BIOMARKER_FOR(Anti-RibP Serum is a highly specific biomarker for SLE) -> highly specific biomarker
# Non-Organ-Specific Biomarkers for SLE - DESCRIBES(The article describes Serum ANA as a biomarker.) -> Serum ANA
# EULAR/ACR-2019 SLE classification - INCLUDES(EULAR/ACR-2019 SLE classification includes immunologic biomarkers.) -> immunologic biomarkers
# TNF - BIOMARKER_FOR(TNF is a biomarker for SLE) -> SLE
# Sm - BIOMARKER_FOR(Sm is a biomarker for SLE) -> SLE
# PON1 - BIOMARKER_FOR(PON1 is a biomarker for SLE) -> SLE
# nLHR - BIOMARKER_FOR(nLHR is a biomarker for SLE) -> SLE
# MHR - BIOMARKER_FOR(MHR is a biomarker for SLE) -> SLE
# MCP-1 - BIOMARKER_FOR(MCP-1 is a biomarker for SLE) -> SLE
# IL - BIOMARKER_FOR(IL is a biomarker for SLE) -> SLE
# IFN - BIOMARKER_FOR(IFN is a biomarker for SLE) -> SLE
# IgG - BIOMARKER_FOR(IgG is a biomarker for SLE) -> SLE
# IP-10 - BIOMARKER_FOR(IP-10 is a biomarker for SLE) -> SLE
# SLE - ASSOCIATED_WITH(Finding an ideal biomarker for SLE) -> biomarker
# biomarker - INCLUDES(biomarker can be reliably measured in fluids) -> fluids
# biomarker - INCLUDES(biomarker can be reliably measured in cells) -> cells
# biomarker - INCLUDES(biomarker can be reliably measured in tissues) -> tissues
# biomarker - AFFECTS(biomarker monitors SLE flares) -> SLE flares
# biomarker - AFFECTS(biomarker monitors SLE activity) -> SLE activity
# biomarker - ASSOCIATED_WITH(biomarker has high specificity) -> high specificity
# biomarker - ASSOCIATED_WITH(biomarker has high sensitivity) -> high sensitivity
# biomarker - ASSOCIATED_WITH(biomarker has high predictive values) -> high predictive values
# biomarker - ASSOCIATED_WITH(biomarker has validity) -> validity
# biomarker - ASSOCIATED_WITH(biomarker has reliability) -> reliability
# biomarker - DESCRIBES(biomarker reflects the treatment target) -> treatment target
# biomarker - DESCRIBES(biomarker reflects the underlying pathophysiology) -> pathophysiology
# combining multiple biomarkers through mathematical models - CONTRIBUTES_TO(multiple biomarkers combined through mathematical models may be a good idea for assessing SLE) -> SLE
# multiple biomarkers - CONTRIBUTES_TO(Multiple biomarkers contribute to understanding SLE.) -> SLE
# coronin-1A - DESCRIBES(coronin-1A is a biomarker of LN) -> biomarker of LN
# dsDNA - BIOMARKER_FOR(dsDNA is a biomarker for SLE) -> SLE
# Serum Anti-Sm Antibody - BIOMARKER_FOR(Anti-Sm antibodies serve as a biomarker for SLE classification) -> SLE
# laboratory biomarkers - INCLUDES(laboratory biomarkers are related to SLE) -> SLE
# laboratory biomarkers - INCLUDES(laboratory biomarkers include lupus erythematosus (LE) cells.) -> lupus erythematosus (LE) cells
# laboratory biomarkers - INCLUDES(laboratory biomarkers include complement (2, 3, and 4).) -> complement (2, 3, and 4)
# laboratory biomarkers - INCLUDES(laboratory biomarkers include total complement activity.) -> total complement activity
# laboratory biomarkers - INCLUDES(laboratory biomarkers include DNA antibody.) -> DNA antibody
# laboratory biomarkers - INCLUDES(laboratory biomarkers include antinuclear antibody (ANA).) -> antinuclear antibody (ANA)
# laboratory biomarkers - INCLUDES(laboratory biomarkers include Smith (Sm) antibody.) -> Smith (Sm) antibody
# laboratory biomarkers - INCLUDES(laboratory biomarkers include platelets.) -> platelets
# laboratory biomarkers - INCLUDES(laboratory biomarkers include lymphocytes.) -> lymphocytes
# laboratory biomarkers - INCLUDES(laboratory biomarkers include white blood cells.) -> white blood cells
# laboratory biomarkers - INCLUDES(laboratory biomarkers include hemolytic anemia with reticulocytosis.) -> hemolytic anemia with reticulocytosis
# laboratory biomarkers - INCLUDES(laboratory biomarkers include urinary casts.) -> urinary casts
# laboratory biomarkers - INCLUDES(laboratory biomarkers include proteinuria.) -> proteinuria
# Rheumatology (ACR) - ASSOCIATED_WITH(Rheumatology (ACR) is associated with laboratory biomarkers.) -> laboratory biomarkers
# College of Rheumatology (ACR) - ASSOCIATED_WITH(ACR contains laboratory biomarkers) -> laboratory biomarkers
# SLE - INCLUDES(Common biomarkers for SLE are included in the study of SLE) -> Common biomarkers for SLE
# biomarker sensitivity and specificity for SLE - AFFECTS(biomarker can be sensitive and specific for SLE) -> SLE
# advanced computational methods for analyzing large datasets - CONTRIBUTES_TO(advanced computational methods are required to analyze large datasets and discover novel biomarkers) -> biomarker sensitivity and specificity for SLE
# K.F. - AUTHORED(K.F. professionally edited the manuscript) -> biomarker sensitivity and specificity for SLE
# Y.N. - AUTHORED(Y.N. professionally edited the manuscript) -> biomarker sensitivity and specificity for SLE
# H.Y. - AUTHORED(H.Y. conceived the presented idea and drafted the manuscript) -> biomarker sensitivity and specificity for SLE
# diagnostic biomarkers - DIAGNOSTIC_FOR(Diagnostic biomarkers are used for NPSLE) -> NPSLE
# NPSLE - CAUSES(NPSLE manifestations are caused by certain antibodies) -> diagnostic biomarkers
# therapeutic biomarker for SLE patients with CVD - PRODUCES(Therapeutic biomarker for SLE patients with CVD produces NPSLE) -> NPSLE
# accelerated atherosclerosis in lupus - BIOMARKER_FOR(Accelerated atherosclerosis in lupus is a biomarker for NPSLE) -> NPSLE
# highly specific biomarker - BIOMARKER_FOR(Anti-RibP is a highly specific biomarker for NPSLE) -> NPSLE
# NPSLE - ASSOCIATED_WITH(NPSLE is associated with diagnostic biomarkers.) -> diagnostic biomarkers
# SLE - AFFECTS(SLE is diagnosed based on laboratory biomarkers.) -> laboratory biomarkers
# Systemic Lupus Erythematosus (SLE) - ASSOCIATED_WITH(SLE is diagnosed based on laboratory biomarkers.) -> laboratory biomarkers
# organ-specific SLE biomarkers - BIOMARKER_FOR(Organ-specific SLE biomarkers are needed for SLE.) -> SLE
# non-organ-specific SLE biomarkers - BIOMARKER_FOR(Non-organ-specific SLE biomarkers are needed for SLE.) -> SLE
# immunological biomarkers - BIOMARKER_FOR(Immunological biomarkers are needed for SLE.) -> SLE
# anti-RibP test - BIOMARKER_FOR(anti-RibP is a biomarker for diagnosing SLE) -> SLE
# anti-C1q antibodies - BIOMARKER_FOR(anti-C1q antibodies may serve as a non-invasive biomarker for predicting renal flares in SLE) -> SLE
# Anti-Sm antibodies - BIOMARKER_FOR(Anti-Sm antibodies are highly specific diagnostic biomarkers for SLE.) -> SLE
# Anti-dsDNA antibodies - BIOMARKER_FOR(Anti-dsDNA antibodies are biomarkers associated with SLE disease activity.) -> SLE
# biomarker for screening, classification, diagnosis, prognosis, and staging - BIOMARKER_FOR(used as a biomarker for) -> SLE
# ideal biomarker for SLE - BIOMARKER_FOR(Ideal biomarker for SLE is a biomarker for SLE) -> SLE
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects the underlying pathophysiology or treatment target) -> underlying pathophysiology or treatment target
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects high sensitivity) -> high sensitivity
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects high predictive values) -> high predictive values
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects validity) -> validity
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects reliability) -> reliability
# biomarker - BIOMARKER_FOR(A biomarker may reflect one specific aspect of SLE) -> SLE
# biomarker - ASSESSES(Biomarkers can be used to detect and/or monitor a biologic process) -> biologic process
# serum cardiac troponin T - BIOMARKER_FOR(serum cardiac troponin T is a biomarker for incident cardiovascular events in SLE patients) -> CVD
# clinical and immunological biomarkers review - DESCRIBES(This article reviews clinical and immunological biomarkers for SLE) -> SLE
# novel SLE biomarkers - BIOMARKER_FOR(Novel SLE biomarkers have been discovered through omics research.) -> Systemic lupus erythematosus (SLE)
# immunological biomarkers - BIOMARKER_FOR(Immunological biomarkers could diagnose and monitor disease activity in SLE.) -> Systemic lupus erythematosus (SLE)
# Biomarker for Staging - USED_FOR(ANA is used as a biomarker for staging of SLE) -> Systemic Lupus Erythematosus (SLE)
# Biomarker for Prognosis - USED_FOR(ANA is used as a biomarker for prognosis of SLE) -> Systemic Lupus Erythematosus (SLE)
# Biomarker for Diagnosis - USED_FOR(ANA is used as a biomarker for diagnosis of SLE) -> Systemic Lupus Erythematosus (SLE)
# Biomarker for Classification - USED_FOR(ANA is used as a biomarker for classification of SLE) -> Systemic Lupus Erythematosus (SLE)
# Biomarker for Screening - USED_FOR(ANA is used as a biomarker for screening SLE) -> Systemic Lupus Erythematosus (SLE)
# anti-dsDNA antibodies - AFFECTS(anti-dsDNA antibodies are an unreliable biomarker for assessing disease activity) -> disease activity
# SLE - AFFECTS(biomarkers reflect disease activity of SLE) -> disease activity
# C4 - BIOMARKER_FOR(C4 levels are biomarkers for SLE) -> Systemic Lupus Erythematosus (SLE)
# C3 - BIOMARKER_FOR(C3 levels are biomarkers for SLE) -> Systemic Lupus Erythematosus (SLE)
# Immunological biomarkers - BIOMARKER_FOR(Immunological biomarkers help in diagnosing SLE) -> Systemic Lupus Erythematosus (SLE)
# Current study on immunological biomarkers for SLE - AUTHORED(Current study reviews immunological biomarkers for SLE) -> Immunological biomarkers
# anticardiolipin antibodies - BIOMARKER_FOR(Anticardiolipin antibodies as a biomarker for immunologic criteria) -> immunologic criteria
# Omics Approaches in SLE - DESCRIBES(Omics approaches provide opportunities for revealing new biomarkers for SLE.) -> Systemic Lupus Erythematosus (SLE)
# biomarkers - USED_FOR(Biomarkers can be used to detect and monitor a biologic process.) -> biologic process
# biomarkers - ASSESSES(Tissues can be measured for biomarkers.) -> tissues
# biomarkers - ASSESSES(Urine can be measured for biomarkers.) -> urine
# biomarkers - ASSESSES(Blood can be measured for biomarkers.) -> blood
# biomarkers - RESULTS_IN(Biomarkers can indicate a morbid state.) -> morbid state
# biomarkers - AFFECTS(biomarkers play a crucial role in management) -> management
# biomarkers - AFFECTS(biomarkers play a crucial role in assessment) -> assessment
# biomarkers - AFFECTS(biomarkers play a crucial role in prediction) -> prediction
# biomarkers - AFFECTS(biomarkers play a crucial role in diagnosis) -> diagnosis
# biomarkers - ASSOCIATED_WITH(biomarkers are used in the diagnosis and management of cancer) -> cancer
# biomarkers - ASSOCIATED_WITH(biomarkers are used in the diagnosis and management of heart disease) -> heart disease
# biomarkers - ASSOCIATED_WITH(biomarkers are used in the diagnosis and management of diabetes) -> diabetes
# biomarkers - ASSOCIATED_WITH(biomarkers are used in the diagnosis and management of SLE) -> SLE

# %%
vc_ls = vc_rag_result.retriever_result.items[0].content.split('\\n---\\n')
for i in vc_ls:
    if "treat" in i: print(i)
# Out:
# <Record info='=== text ===\nSLE, classifying SLE complications, \nassessing SLE disease activity, and reflecting the therapeutic effect of interventions for \nSLE. Common biomarkers for SLE and their me asurement sites in patients with SLE are \nhighlighted in Figure 1. Finding an ideal biomarker for SLE is challenging because it should have the following characteristics: (1 ) reflect the underlying pathophysiology or \ntreatment target; (2) have reliability, validity, high predictive values, and high sensitivity \nand
# biomarker - DESCRIBES(biomarker reflects the treatment target) -> treatment target
# treatment decisions - USED_FOR(Treatment decisions are made for NPSLE) -> NPSLE
# NPSLE - RESULTS_IN(NPSLE is used to make treatment decisions) -> treatment decisions
# NPSLE - AFFECTS(NPSLE affects treatment decisions) -> treatment decisions
# ideal biomarker for SLE - AFFECTS(Ideal biomarker for SLE affects the underlying pathophysiology or treatment target) -> underlying pathophysiology or treatment target
# Diagnosis - ASSESSES(Early diagnosis is critical for effective treatment) -> Systemic Lupus Erythematosus (SLE)

# %%
q = "Can you summarize systemic lupus erythematosus (SLE)? including common effects, biomarkers, treatments, and current challenges faced by Physicians and patients? provide in list format with details for each item."
print(f"Vector Response: \n{v_rag.search(q, retriever_config={'top_k': 5}).answer}")
print("\n===========================\n")
print(f"Vector + Cypher Response: \n{vc_rag.search(q, retriever_config={'top_k': 5}).answer}")
# Out:
# Vector Response:
# - **Common Effects of SLE:**
#   - SLE is a systemic autoimmune disease characterized by aberrant activity of the immune system.
#   - It presents with a wide range of clinical symptoms and signs affecting various organs.
#
# - **Biomarkers for SLE:**
#   - Biomarkers are used to diagnose and monitor disease activity in SLE, with and without organ-specific injury.
#   - Common biomarkers include:
#     - Anti-dsDNA antibodies: Associated with SLE disease activity and can predict the development of lupus nephritis (LN); high specificity (96%), low diagnostic sensitivity (52–70%).
#     - Anti-Sm antibodies: Correlates with SLE disease activity and LN; highly specific diagnostic biomarker for SLE with a specificity of 99%.
#
# - **Treatments for SLE:**
#   - The context does not provide specific treatments for SLE.
#
# - **Current Challenges:**
#   - Finding an ideal biomarker for SLE is challenging because it should reflect the underlying pathophysiology or treatment target, have reliability, validity, high predictive values, and high sensitivity.
#   - Developing consistent classification criteria for SLE for research and clinical diagnosis is necessary. The most widely used classification criteria were established by the American College of Rheumatology (ACR).
#
# ===========================
#
# Vector + Cypher Response:
# - **Systemic Lupus Erythematosus (SLE) Overview:**
#   - SLE is a systemic autoimmune disease characterized by aberrant activity of the immune system and presents with a wide range of clinical manifestations.
#
# - **Common Effects:**
#   - SLE can cause damage to various organs, including the kidneys (lupus nephritis), skin lesions, and cardiovascular disease (CVD).
#   - It is associated with symptoms such as cardiovascular, neuropsychiatric, dermatological, and renal symptoms.
#
# - **Biomarkers:**
#   - Common biomarkers include anti-dsDNA antibodies, anti-Sm antibodies, and antinuclear antibodies (ANA).
#   - Biomarkers are used for diagnosis, monitoring disease activity, and predicting complications like lupus nephritis.
#   - Ideal biomarkers should reflect the underlying pathophysiology, have high sensitivity, specificity, predictive values, reliability, and validity.
#
# - **Treatments:**
#   - Treatment aims to control SLE and manage symptoms, though the disease cannot be completely cured.
#   - Therapeutic interventions are assessed for their effect on disease activity.
#
# - **Current Challenges:**
#   - Finding an ideal biomarker for SLE is challenging due to the need for high sensitivity, specificity, and the ability to reflect treatment targets.
#   - Physicians and patients face challenges in diagnosing and classifying SLE due to its complex nature and the need for consistent classification criteria.
#   - The disease's wide range of clinical manifestations and potential for multiple organ damage complicate management and treatment decisions.
